# %%
from jaqs_fxdayu.util import dp
from jaqs.data.dataapi import DataApi
import pandas as pd
from jaqs_fxdayu.research.signaldigger import multi_factor


api = DataApi(addr='tcp://data.tushare.org:8910')
api.login("13660419968", 
          'eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjI0ODUwODIyOTgiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjA0MTk5NjgifQ.CCxBUJzywVCCmhaJSEnHr_THpalcRRIoA1biUWd7Hj8'
)

start = 20100101
end = 20180401
SH_id = dp.index_cons(api, "000300.SH", start, end)
SZ_id = dp.index_cons(api, "000905.SH", start, end)

stock_symbol = list(set(SH_id.symbol)|set(SZ_id.symbol))
# Out:
# C:\Users\Administrator\Anaconda3\lib\importlib\__init__.py:126: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   return _bootstrap._gcd_import(name[level:], package, level)
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
factor_list = ['volume']
check_factor = ','.join(factor_list)

# %%
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910",
"remote.data.username": "13662241013",
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTc2NDQzMzg5MTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjIyNDEwMTMifQ.sVIzI5VLqq8fbZCW6yZZW0ClaCkcZpFqpiK944AHEow"
}

ds = RemoteDataService()
ds.init_from_config(data_config)
zz800_close = ds.daily('000906.SH', 20160501, 20180401, fields="close", adjust_mode=None)
zz800_benchmark = zz800_close[0][['trade_date','close']].set_index('trade_date')
zz800_benchmark.head()

# %%
import jaqs_fxdayu
jaqs_fxdayu.patch_all()
from jaqs.data import DataView
from jaqs.data import RemoteDataService
from jaqs_fxdayu.data.dataservice import LocalDataService
import os
import numpy as np
import warnings
warnings.filterwarnings("ignore")

dataview_folder = r'D:\data'
dv = DataView()
ds = LocalDataService(fp=dataview_folder)
dv_props = {'start_date': start, 'end_date': end, 'symbol':','.join(stock_symbol),
         'fields': check_factor,
         'freq': 1,
         "prepare_fields": True}

dv.init_from_config(dv_props, data_api=ds)
dv.prepare_data()
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'trade_status,open_adj,volume,close,symbol,vwap_adj,low_adj,high_adj,close_adj,low,trade_date,open,high,vwap'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'close,low,open,high,vwap,symbol,trade_date'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
dv.add_field('sw1')
# Out:
# True

# %%
sw1 = dv.get_ts('sw1')

# %%
dict_classify = {'480000': '银行', '430000': '房地产', '460000': '休闲服务', '640000': '机械设备', '240000': '有色金属', '510000': '综合', '410000': '公用事业', '450000': '商业贸易', '730000': '通信', '330000': '家用电器', '720000': '传媒', '630000': '电气设备', '270000': '电子', '490000': '非银金融', '370000': '医药生物', '710000': '计算机', '280000': '汽车', '340000': '食品饮料', '220000': '化工', '210000': '采掘', '230000': '钢铁', '650000': '国防军工', '110000': '农林牧渔', '420000': '交通运输', '620000': '建筑装饰', '350000': '纺织服装', '610000': '建筑材料', '360000': '轻工制造'}

# %%
sw1_name = sw1.replace(dict_classify)

# %%
sw1_name.tail()
# Out:
# symbol     000001.SZ 000002.SZ 000005.SZ 000006.SZ 000008.SZ 000009.SZ  \
# trade_date
# 20180326          银行       房地产      公用事业       房地产      机械设备        综合
# 20180327          银行       房地产      公用事业       房地产      机械设备        综合
# 20180328          银行       房地产      公用事业       房地产      机械设备        综合
# 20180329          银行       房地产      公用事业       房地产      机械设备        综合
# 20180330          银行       房地产      公用事业       房地产      机械设备        综合
#
# symbol     000012.SZ 000016.SZ 000021.SZ 000022.SZ    ...    603833.SH  \
# trade_date                                            ...
# 20180326        建筑材料      家用电器       计算机      交通运输    ...         轻工制造
# 20180327        建筑材料      家用电器       计算机      交通运输    ...         轻工制造
# 20180328        建筑材料      家用电器       计算机      交通运输    ...         轻工制造
# 20180329        建筑材料      家用电器       计算机      交通运输    ...         轻工制造
# 20180330        建筑材料      家用电器       计算机      交通运输    ...         轻工制造
#
# symbol     603858.SH 603866.SH 603868.SH 603877.SH 603883.SH 603885.SH  \
# trade_date
# 20180326        医药生物      食品饮料      家用电器      纺织服装      医药生物      交通运输
# 20180327        医药生物      食品饮料      家用电器      纺织服装      医药生物      交通运输
# 20180328        医药生物      食品饮料      家用电器      纺织服装      医药生物      交通运输
# 20180329        医药生物      食品饮料      家用电器      纺织服装      医药生物      交通运输
# 20180330        医药生物      食品饮料      家用电器      纺织服装      医药生物      交通运输
#
# symbol     603888.SH 603899.SH 603993.SH
# trade_date
# 20180326          传媒      轻工制造      有色金属
# 20180327          传媒      轻工制造      有色金属
# 20180328          传媒      轻工制造      有色金属
# 20180329          传媒      轻工制造      有色金属
# 20180330          传媒      轻工制造      有色金属
#
# [5 rows x 1405 columns]

# %%
id_zz500 = dp.daily_index_cons(api, "000300.SH", start, end)
id_hs300 = dp.daily_index_cons(api, "000905.SH", start, end)
columns_500 = list(set(id_zz500.columns)-set(id_hs300.columns))
id_member = pd.concat([id_zz500[columns_500],id_hs300],axis=1)
mask = ~id_member
price = dv.get_ts('close_adj')
mask = mask.reindex(index=price.index)
mask.colunms = price.columns

# %%
alpha1 = dv.add_formula('alpha1', 'close-Ts_Mean(close,25)/Ts_Mean(close,15)', is_quarterly=False, add_data=True)
dv.add_field('undistributed_profit',ds)
dv.add_field('surplus_rsrv',ds)
alpha2 = dv.add_formula('alpha2', '-1*(undistributed_profit+surplus_rsrv+close)/3', is_quarterly=False , add_data = True)
alpha3 = dv.add_formula('alpha3', '(high-low)/Delay(close,1)', is_quarterly=False , add_data = True)
alpha4 = dv.add_formula('alpha4','-1*(1-Rank(close/Delay(close,30)-1)/1000)',is_quarterly = False , add_data = True)
alpha5 = dv.add_formula('alpha5','Correlation(turnover_ratio,Return(close,20),5)',is_quarterly = False , add_data = True)
alpha6 = dv.add_formula('alpha6','-1*(roe+50/pe_ttm)',is_quarterly = True ,add_data = True)
dv.add_formula('right','volume/Ts_Sum(volume,10)',is_quarterly = False,add_data = True)
alpha7 = dv.add_formula('alpha7','Ts_Mean(close*right,10)',is_quarterly = False , add_data = True)
alpha8 = dv.add_formula('alpha8','If((close-Ts_Max(high,17))>0,close, 2*close-Ts_Mean(close,17))',is_quarterly = False , add_data = True)
alpha9 = dv.add_formula('alpha9','If((Ts_Min(low,17)-close)>0 ,close ,close-Ts_Min(low,17))',is_quarterly = False , add_data = True)
dv.add_formula('MEAN','Ts_Mean(close,5)',is_quarterly = False, add_data = True)
alpha10 = dv.add_formula('alpha10', "Ta('LINEARREG_SLOPE',0,MEAN,MEAN,MEAN,MEAN,MEAN,5)", is_quarterly = False,add_data = True)
dv.add_formula('alpha11','Return(tot_profit)',is_quarterly = True , add_data = True)
dv.add_field('pb',ds)
dv.add_field('pe',ds)
dv.add_field('ps',ds)
dv.add_field('free_turnover_ratio',ds)
dv.add_formula('alpha12','pb+pe+ps',is_quarterly = False , add_data = True)
dv.add_formula('alpha13','-1*Ts_Sum(free_turnover_ratio,20)',is_quarterly = False , add_data = True)
dv.add_formula('alpha14','Ts_Mean(Abs((close-Delay(close,1))/Delay(close,1))/volume,20)',is_quarterly = False , add_data = True)
# Out:
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000602.SZ, 000748.SZ, 600005.SH, 600087.SH, 600102.SH, 600263.SH, 600553.SH, 600607.SH, 600631.SH, 600832.SH, 600991.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000602.SZ, 000748.SZ, 600005.SH, 600087.SH, 600102.SH, 600263.SH, 600553.SH, 600607.SH, 600631.SH, 600832.SH, 600991.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000602.SZ, 000748.SZ, 600005.SH, 600087.SH, 600102.SH, 600263.SH, 600553.SH, 600607.SH, 600631.SH, 600832.SH, 600991.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Variable [turnover_ratio] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,turnover_ratio,trade_date'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Variable [roe] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 600607.SH
# Query data - quarterly fields prepared.
# Variable [pe_ttm] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,pe_ttm,trade_date'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Variable [tot_profit] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000602.SZ, 000748.SZ, 600005.SH, 600087.SH, 600102.SH, 600263.SH, 600553.SH, 600607.SH, 600631.SH, 600832.SH, 600991.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,pb,trade_date'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'pe,trade_date,symbol'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,ps,trade_date'}
# 下载进度244/1405.
# 下载进度488/1405.
# 下载进度732/1405.
# 下载进度976/1405.
# 下载进度1220/1405.
# Query data - daily fields prepared.
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol
# 20100120             NaN  4.337209e-09      ...                NaN
# 20100121             NaN  4.031137e-09      ...                NaN
# 20100122             NaN  4.395172e-09      ...                NaN
# 20100125             NaN  4.958279e-09      ...                NaN
# 20100126    1.579138e-09  5.275966e-09      ...                NaN
# 20100127    1.560991e-09  5.387715e-09      ...                NaN
# 20100128    1.628813e-09  5.687982e-09      ...                NaN
# 20100129    1.532972e-09  5.989893e-09      ...                NaN
# 20100201    1.756096e-09  5.999226e-09      ...                NaN
# 20100202    1.836899e-09  6.157854e-09      ...                NaN
# 20100203    1.875447e-09  6.299466e-09      ...                NaN
# 20100204    1.888397e-09  6.058245e-09      ...                NaN
# 20100205    2.014403e-09  6.341393e-09      ...                NaN
# 20100208    2.064156e-09  6.524118e-09      ...                NaN
# 20100209    2.111910e-09  6.406317e-09      ...                NaN
# 20100210    2.157865e-09  6.982968e-09      ...                NaN
# 20100211    2.185417e-09  7.079139e-09      ...                NaN
# 20100212    2.174372e-09  7.661509e-09      ...                NaN
# ...                  ...           ...      ...                ...
# 20180212    9.136411e-10           NaN      ...       3.615551e-08
# 20180213    9.181095e-10           NaN      ...       3.641696e-08
# 20180214    8.949700e-10           NaN      ...       3.876151e-08
# 20180222    9.521177e-10           NaN      ...       3.993050e-08
# 20180223    9.730651e-10           NaN      ...       3.853855e-08
# 20180226    1.020485e-09           NaN      ...       3.894367e-08
# 20180227    1.015734e-09           NaN      ...       3.730871e-08
# 20180228    1.016584e-09           NaN      ...       3.731255e-08
# 20180301    1.047945e-09           NaN      ...       3.737782e-08
# 20180302    1.066857e-09           NaN      ...       3.608626e-08
# 20180305    1.072902e-09           NaN      ...       3.428237e-08
# 20180306    1.026775e-09           NaN      ...       3.332714e-08
# 20180307    1.020934e-09           NaN      ...       3.237823e-08
# 20180308    9.657026e-10           NaN      ...       3.414803e-08
# 20180309    9.828797e-10           NaN      ...       3.447239e-08
# 20180312    9.376083e-10           NaN      ...       3.413090e-08
# 20180313    8.400113e-10           NaN      ...       3.236028e-08
# 20180314    8.629819e-10           NaN      ...       3.274081e-08
# 20180315    7.871167e-10           NaN      ...       3.274961e-08
# 20180316    6.912876e-10           NaN      ...       2.963375e-08
# 20180319    6.072369e-10           NaN      ...       2.600699e-08
# 20180320    6.190500e-10           NaN      ...       2.629878e-08
# 20180321    6.126786e-10           NaN      ...       2.430514e-08
# 20180322    5.779360e-10           NaN      ...       2.605246e-08
# 20180323    6.908851e-10           NaN      ...       2.851364e-08
# 20180326    6.617571e-10           NaN      ...       2.808209e-08
# 20180327    7.441580e-10           NaN      ...       3.205967e-08
# 20180328    7.617983e-10           NaN      ...       3.500368e-08
# 20180329    7.642005e-10           NaN      ...       4.006861e-08
# 20180330    8.006712e-10           NaN      ...       3.902136e-08
#
# symbol         603858.SH     603866.SH     603868.SH     603877.SH  \
# trade_date
# 20100104             NaN           NaN           NaN           NaN
# 20100105             NaN           NaN           NaN           NaN
# 20100106             NaN           NaN           NaN           NaN
# 20180313    1.989497e-08  4.972370e-09  7.113154e-09  8.328605e-09
# 20180314    2.132583e-08  4.862458e-09  7.097852e-09  8.138231e-09
# 20180315    2.304890e-08  4.877081e-09  6.615046e-09  7.622939e-09
# 20180316    2.367245e-08  4.340849e-09  5.747836e-09  7.382182e-09
# 20180319    2.234386e-08  4.149196e-09  4.803259e-09  7.256691e-09
# 20180320    2.202316e-08  3.537129e-09  5.056484e-09  7.582752e-09
# 20180321    2.255987e-08  3.532902e-09  4.749518e-09  7.204190e-09
# 20180322    1.858495e-08  2.992771e-09  4.361250e-09  7.266927e-09
# 20180323    1.828767e-08  3.356582e-09  4.844971e-09  7.820904e-09
# 20180326    1.567646e-08  3.176576e-09  3.966170e-09  7.844141e-09
# 20180327    1.537573e-08  3.502567e-09  4.459382e-09  8.169309e-09
# 20180328    1.576002e-08  3.718157e-09  4.800472e-09  7.483525e-09
# 20180329    1.617386e-08  3.934188e-09  4.960222e-09  7.451469e-09
# 20180330    1.642890e-08  3.745076e-09  4.987140e-09  7.897799e-09
#
# symbol         603993.SH
# trade_date
# 20100104             NaN
# 20100105             NaN
# 20100106             NaN
# 20100107             NaN
# 20100108             NaN
# 20100111             NaN
# 20100112             NaN
# 20100113             NaN
# 20100114             NaN
# 20100115             NaN
# 20100118             NaN
# 20100119             NaN
# 20100120             NaN
# 20100121             NaN
# 20100122             NaN
# 20100125             NaN
# 20100126             NaN
# 20100127             NaN
# 20100128             NaN
# 20100129             NaN
# 20100201             NaN
# 20100202             NaN
# 20100203             NaN
# 20100204             NaN
# 20100205             NaN
# 20100208             NaN
# 20100209             NaN
# 20100210             NaN
# 20100211             NaN
# 20100212             NaN
# ...                  ...
# 20180212    1.530288e-10
# 20180213    1.492955e-10
# 20180214    1.628534e-10
# 20180222    2.100005e-10
# 20180223    2.187984e-10
# 20180226    2.196643e-10
# 20180227    2.246227e-10
# 20180228    2.253183e-10
# 20180301    2.280474e-10
# 20180302    2.184071e-10
# 20180305    2.257017e-10
# 20180306    2.152895e-10
# 20180307    2.164500e-10
# 20180308    2.178873e-10
# 20180309    2.064060e-10
# 20180312    2.120897e-10
# 20180313    1.955879e-10
# 20180314    1.899382e-10
# 20180315    1.876628e-10
# 20180316    1.674480e-10
# 20180319    1.578364e-10
# 20180320    1.541890e-10
# 20180321    1.465996e-10
# 20180322    9.938906e-11
# 20180323    1.038618e-10
# 20180326    1.052607e-10
# 20180327    1.030292e-10
# 20180328    1.091900e-10
# 20180329    1.067367e-10
# 20180330    1.062357e-10
#
# [2003 rows x 1405 columns]

# %%
import numpy as np


def limit_up_down():
    # 定义可买卖条件——未停牌、未涨跌停
    trade_status = dv.get_ts('trade_status')
    mask_sus = trade_status == 0
    # 涨停
    dv.add_formula('up_limit', '(close - Delay(close, 1)) / Delay(close, 1) > 0.095', is_quarterly=False, add_data=True)
    # 跌停
    dv.add_formula('down_limit', '(close - Delay(close, 1)) / Delay(close, 1) < -0.095', is_quarterly=False, add_data=True)
    can_enter = np.logical_and(dv.get_ts('up_limit') < 1, ~mask_sus) # 未涨停未停牌
    can_exit = np.logical_and(dv.get_ts('down_limit') < 1, ~mask_sus) # 未跌停未停牌
    return can_enter,can_exit


can_enter,can_exit = limit_up_down()

# %%
from jaqs_fxdayu.research.signaldigger import process
def Pretreatment(alpha):
    factor_dict = dict()
    for name in alpha:
        signal = -1*dv.get_ts(name).loc[:20170101] # 调整符号
    #print(signal)
        process.winsorize(factor_df=signal,alpha=0.05,index_member=mask.loc[:2016090])#去极值
    
    #signal = process.rank_standardize(signal,index_member) #因子在截面排序并归一化到0-1(只保留排序信息)
#      行业市值中性化
        signal = process.neutralize(signal,
                                group=dv.get_ts("sw1").loc[:20170101],# 行业分类标准
                                #float_mv = dv.get_ts("float_mv"), #流通市值 可为None 则不进行市值中性化
                                # 是否只处理时只考虑指数成份股
                                )
        signal = process.standardize(signal,index_member=mask.loc[:20170101]) #z-score标准化 保留排序信息和分布信息
        factor_dict[name] = signal
    return factor_dict

# %%
#best part
factor_1 = Pretreatment(["alpha6","alpha5","alpha9"])
factor_2 = Pretreatment(["alpha12","alpha13","alpha6"])
factor_3 = Pretreatment(["alpha12","alpha13","alpha8"])
factor_4 = Pretreatment(["alpha14","alpha13","alpha3"])

# %%
mask.columns = price.columns

# %%
# rollback_period代表滚动窗口所用到的天数,即用前多少期的数据来计算现阶段的因子权重。 通常建议设置时间在半年以上,可以获得相对稳定的预期结果
#  多因子组合-动态加权参数配置
props = {
    'price':dv.get_ts("close_adj").loc[:20170101],
    'high':dv.get_ts("high_adj").loc[:20170101], # 可为空
    'low':dv.get_ts("low_adj").loc[:20170101],# 可为空
    'ret_type': 'return',#可选参数还有upside_ret/downside_ret 则组合因子将以优化潜在上行、下行空间为目标
    'benchmark_price': dv.data_benchmark,  # 为空计算的是绝对收益　不为空计算相对收益
    'period': 20, # 20天的持有期
    'mask': mask.loc[:20170101],
    'can_enter': can_enter.loc[:20170101],
    'can_exit': can_exit.loc[:20170101],
    'forward': True,
    'commission': 0.0008,
    "covariance_type": "shrink",  # 协方差矩阵估算方法 还可以为"simple"
    "rollback_period": 120}  # 滚动窗口天数

# %%
from jaqs_fxdayu.research.signaldigger.multi_factor import combine_factors
def multi(factor_dict):
    comb_factors = dict()
    #for method in ['equal_weight',"ic_weight","ir_weight","max_IR","max_IC"]:
    for method in ['equal_weight',"ic_weight"]:
        comb_factors[method] = combine_factors(factor_dict,
                                                standardize_type="rank",
                                                winsorization=False,
                                                weighted_method=method,
                                                props=props)
        print(method)
        print(comb_factors[method].dropna(how="all").head())
    return comb_factors

# %%
comb_factor_1 = multi(factor_1)
comb_factor_2 = multi(factor_2)
comb_factor_3 = multi(factor_3)
comb_factor_4 = multi(factor_4)
# Out:
# equal_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100104          NaN        NaN        NaN        NaN    ...            NaN
# 20100105          NaN        NaN        NaN        NaN    ...            NaN
# 20100106          NaN        NaN        NaN        NaN    ...            NaN
# 20100107          NaN        NaN        NaN        NaN    ...            NaN
# 20100108          NaN        NaN        NaN        NaN    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100104          NaN        NaN        NaN
# 20100105          NaN        NaN        NaN
# 20100106          NaN        NaN        NaN
# 20100107          NaN        NaN        NaN
# 20100108          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# ic_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN   0.181598   0.760291
# 20100802          NaN        NaN        NaN        NaN   0.161446   0.761446
# 20100803          NaN        NaN        NaN        NaN   0.238554   0.732530
# 20100804          NaN        NaN        NaN        NaN   0.253012   0.761446
# 20100805          NaN        NaN        NaN        NaN   0.132530   0.732530
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100730     0.830508        NaN   0.375303   0.757869    ...            NaN
# 20100802     0.828916        NaN   0.383133   0.734940    ...            NaN
# 20100803     0.824096        NaN   0.395181   0.792771    ...            NaN
# 20100804     0.853012        NaN   0.390361   0.775904    ...            NaN
# 20100805     0.840964        NaN   0.397590   0.802410    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN        NaN        NaN
# 20100802          NaN        NaN        NaN        NaN        NaN        NaN
# 20100803          NaN        NaN        NaN        NaN        NaN        NaN
# 20100804          NaN        NaN        NaN        NaN        NaN        NaN
# 20100805          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100730          NaN        NaN        NaN
# 20100802          NaN        NaN        NaN
# 20100803          NaN        NaN        NaN
# 20100804          NaN        NaN        NaN
# 20100805          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# equal_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100104          NaN        NaN        NaN        NaN    ...            NaN
# 20100105          NaN        NaN        NaN        NaN    ...            NaN
# 20100106          NaN        NaN        NaN        NaN    ...            NaN
# 20100107          NaN        NaN        NaN        NaN    ...            NaN
# 20100108          NaN        NaN        NaN        NaN    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100104          NaN        NaN        NaN
# 20100105          NaN        NaN        NaN
# 20100106          NaN        NaN        NaN
# 20100107          NaN        NaN        NaN
# 20100108          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%
# ic_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN   0.408551   0.422803
# 20100802          NaN        NaN        NaN        NaN   0.428910   0.398104
# 20100803          NaN        NaN        NaN        NaN   0.405213   0.386256
# 20100804          NaN        NaN        NaN        NaN   0.383886   0.390995
# 20100805          NaN        NaN        NaN        NaN   0.334123   0.395735
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100730     0.976247        NaN   0.396675   0.610451    ...            NaN
# 20100802     0.976303        NaN   0.390995   0.599526    ...            NaN
# 20100803     0.969194        NaN   0.407583   0.609005    ...            NaN
# 20100804     0.966825        NaN   0.407583   0.620853    ...            NaN
# 20100805     0.964455        NaN   0.424171   0.632701    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN        NaN        NaN
# 20100802          NaN        NaN        NaN        NaN        NaN        NaN
# 20100803          NaN        NaN        NaN        NaN        NaN        NaN
# 20100804          NaN        NaN        NaN        NaN        NaN        NaN
# 20100805          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100730          NaN        NaN        NaN
# 20100802          NaN        NaN        NaN
# 20100803          NaN        NaN        NaN
# 20100804          NaN        NaN        NaN
# 20100805          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# equal_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN   0.082725   0.296837
# 20100105          NaN        NaN        NaN        NaN   0.082725   0.347932
# 20100106          NaN        NaN        NaN        NaN   0.077670   0.347087
# 20100107          NaN        NaN        NaN        NaN   0.055825   0.361650
# 20100108          NaN        NaN        NaN        NaN   0.058111   0.397094
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100104     0.087591        NaN   0.717762        NaN    ...            NaN
# 20100105     0.104623        NaN   0.725061        NaN    ...            NaN
# 20100106     0.094660        NaN   0.689320        NaN    ...            NaN
# 20100107     0.114078        NaN   0.645631        NaN    ...            NaN
# 20100108     0.135593        NaN   0.675545        NaN    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100104          NaN        NaN        NaN
# 20100105          NaN        NaN        NaN
# 20100106          NaN        NaN        NaN
# 20100107          NaN        NaN        NaN
# 20100108          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# ic_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN   0.767782   0.253138
# 20100802          NaN        NaN        NaN        NaN   0.768267   0.237996
# 20100803          NaN        NaN        NaN        NaN   0.751566   0.237996
# 20100804          NaN        NaN        NaN        NaN   0.747390   0.237996
# 20100805          NaN        NaN        NaN        NaN   0.734864   0.233820
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100730     0.732218        NaN   0.336820   0.378661    ...            NaN
# 20100802     0.743215        NaN   0.329854   0.384134    ...            NaN
# 20100803     0.726514        NaN   0.334029   0.379958    ...            NaN
# 20100804     0.709812        NaN   0.311065   0.396660    ...            NaN
# 20100805     0.701461        NaN   0.306889   0.405010    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN        NaN        NaN
# 20100802          NaN        NaN        NaN        NaN        NaN        NaN
# 20100803          NaN        NaN        NaN        NaN        NaN        NaN
# 20100804          NaN        NaN        NaN        NaN        NaN        NaN
# 20100805          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100730          NaN        NaN        NaN
# 20100802          NaN        NaN        NaN
# 20100803          NaN        NaN        NaN
# 20100804          NaN        NaN        NaN
# 20100805          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# equal_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN   0.741007
# 20100105          NaN        NaN        NaN        NaN        NaN   0.351064
# 20100106          NaN        NaN        NaN        NaN        NaN   0.416961
# 20100107          NaN        NaN        NaN        NaN        NaN   0.242958
# 20100108          NaN        NaN        NaN        NaN        NaN   0.328571
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100104     0.697842        NaN        NaN        NaN    ...            NaN
# 20100105     0.475177        NaN        NaN        NaN    ...            NaN
# 20100106     0.155477        NaN        NaN        NaN    ...            NaN
# 20100107     0.056338        NaN        NaN        NaN    ...            NaN
# 20100108     0.489286        NaN        NaN        NaN    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100104          NaN        NaN        NaN        NaN        NaN        NaN
# 20100105          NaN        NaN        NaN        NaN        NaN        NaN
# 20100106          NaN        NaN        NaN        NaN        NaN        NaN
# 20100107          NaN        NaN        NaN        NaN        NaN        NaN
# 20100108          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100104          NaN        NaN        NaN
# 20100105          NaN        NaN        NaN
# 20100106          NaN        NaN        NaN
# 20100107          NaN        NaN        NaN
# 20100108          NaN        NaN        NaN
#
# [5 rows x 1405 columns]
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 17%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# ic_weight
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN   0.759791   0.080940
# 20100802          NaN        NaN        NaN        NaN   0.750649   0.072727
# 20100803          NaN        NaN        NaN        NaN   0.739691   0.033505
# 20100804          NaN        NaN        NaN        NaN   0.761658   0.080311
# 20100805          NaN        NaN        NaN        NaN   0.676240   0.075718
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20100730     0.078329        NaN   0.096606   0.785901    ...            NaN
# 20100802     0.132468        NaN   0.062338   0.823377    ...            NaN
# 20100803     0.082474        NaN   0.064433   0.762887    ...            NaN
# 20100804     0.056995        NaN   0.059585   0.852332    ...            NaN
# 20100805     0.054830        NaN   0.062663   0.775457    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20100730          NaN        NaN        NaN        NaN        NaN        NaN
# 20100802          NaN        NaN        NaN        NaN        NaN        NaN
# 20100803          NaN        NaN        NaN        NaN        NaN        NaN
# 20100804          NaN        NaN        NaN        NaN        NaN        NaN
# 20100805          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20100730          NaN        NaN        NaN
# 20100802          NaN        NaN        NaN
# 20100803          NaN        NaN        NaN
# 20100804          NaN        NaN        NaN
# 20100805          NaN        NaN        NaN
#
# [5 rows x 1405 columns]

# %%
def get_ic_df(comb_factors):
    ic_20  =   multi_factor.get_factors_ic_df(comb_factors,
                                          price=dv.get_ts("close_adj").loc[:20170101],
                                          high=dv.get_ts("high_adj").loc[:20170101], # 可为空
                                          low=dv.get_ts("low_adj").loc[:20170101],# 可为空
                                          n_quantiles=5,# quantile分类数
                                          mask=mask.loc[:20170101],# 过滤条件
                                          can_enter=can_enter.loc[:20170101],# 是否能进场
                                          can_exit=can_exit.loc[:20170101],# 是否能出场
                                          period=20,#有期
                                          benchmark_price=zz800_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                          commission = 0.0008,
                                          )

    return ic_20

# %%
factor_ic_1 = get_ic_df(comb_factor_1)
factor_ic_2 = get_ic_df(comb_factor_2)
factor_ic_3 = get_ic_df(comb_factor_3)
factor_ic_4 = get_ic_df(comb_factor_4)
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 15%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 15%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 19%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 18%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 17%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%

# %%
import datetime
def get_ir(ic_20):
    ic_20_mean = dict()
    ic_20_std = dict()
    ir_20 = dict()
    for name in ic_20.columns:    
        ic_20_mean[name]=ic_20[name].loc[:20170101].mean()
        ic_20_std[name]=ic_20[name].loc[:20170101].std()
        ir_20[name] = ic_20_mean[name]/ic_20_std[name]


    trade_date = pd.Series(ic_20.index)
    trade_date = trade_date.apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))
    ic_20.index = trade_date
    pd.Series(ic_20_mean).plot(kind="barh",xerr=pd.Series(ic_20_std),figsize=(15,5))
    pd.Series(ir_20).plot(kind="barh",figsize=(15,5))
    return ir_20

# %%
#ir_1 = get_ir(factor_ic_1)
#ir_2 = get_ir(factor_ic_2)
#ir_3 = get_ir(factor_ic_3)
#ir_4 = get_ir(factor_ic_4)

# %%
import matplotlib.pyplot as plt
from jaqs_fxdayu.research.signaldigger.analysis import analysis
from jaqs_fxdayu.research import SignalDigger
def result_with_benchmark(comb_factors,name,method):
    obj = SignalDigger(output_folder="相对收益样本内2010-2017/%s" % name,
                       output_format='pdf')
    obj.process_signal_before_analysis(signal=comb_factors[method].loc[:20170101],
                                   price=dv.get_ts("close_adj").loc[:20170101],
                                   high=dv.get_ts("high_adj").loc[:20170101], # 可为空
                                   low=dv.get_ts("low_adj").loc[:20170101],# 可为空
                                   n_quantiles=5,# quantile分类数
                                   mask=mask.loc[:20170101],# 过滤条件
                                   can_enter=can_enter.loc[:20170101],# 是否能进场
                                   can_exit=can_exit.loc[:20170101],# 是否能出场
                                   period=20,# 持有期
                                   benchmark_price=zz800_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                   commission = 0.0008,
                                   )
    obj.create_full_report()
    plt.show()
    print(analysis(obj.signal_data,is_event=False,period=20))

# %%
result_with_benchmark(comb_factor_1,'factor_1_benchmark',"ic_weight")
result_with_benchmark(comb_factor_2,'factor_2_benchmark',"ic_weight")
result_with_benchmark(comb_factor_3,'factor_3_benchmark',"ic_weight")
result_with_benchmark(comb_factor_4,'factor_4_benchmark',"ic_weight")
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 15%
#
#
# Value of signals of Different Quantiles Statistics
#                min       max      mean       std  count    count %
# quantile
# 1         0.000000  0.320879  0.105229  0.061601  74235  20.166088
# 2         0.130930  0.505495  0.308274  0.061451  73632  20.002282
# 3         0.261438  0.932203  0.504069  0.060703  73622  19.999565
# 4         0.529412  0.859341  0.700527  0.060781  73632  20.002282
# 5         0.721133  1.000000  0.899942  0.059385  72997  19.829783
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_1\returns_report.pdf
# Information Analysis
#                  ic
# IC Mean       0.040
# IC Std.       0.110
# t-stat(IC)   14.198
# p-value(IC)   0.000
# IC Skew       0.535
# IC Kurtosis   3.942
# Ann. IR       0.362
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_1\information_report.pdf
# {'ic':                 return_ic  upside_ret_ic  downside_ret_ic
# IC Mean      3.964795e-02       0.007929     3.679585e-02
# IC Std.      1.095844e-01       0.103139     1.140765e-01
# t-stat(IC)   1.419817e+01       3.017002     1.265794e+01
# p-value(IC)  4.353026e-43       0.002595     5.256952e-35
# IC Skew      5.349827e-01       0.913010    -2.263226e-01
# IC Kurtosis  3.941661e+00       5.803595     5.294109e+00
# Ann. IR      3.618029e-01       0.076880     3.225541e-01, 'ret':               long_ret  long_short_ret  top_quantile_ret  bottom_quantile_ret  \
# t-stat        7.388285       11.961827         38.697434            21.073642
# p-value       0.000000        0.000000          0.000000             0.000000
# skewness     -0.494118        3.777639          1.070830             0.739243
# kurtosis      3.557607       52.686531          7.067111             4.391435
# Ann. Ret      0.225027        0.053510          0.254202             0.133309
# Ann. Vol      0.345718        0.050777          0.510216             0.495483
# Ann. IR       0.650899        1.053822          0.498225             0.269049
# occurance  1560.000000     1560.000000      72997.000000         74235.000000
#
#                tmb_ret  all_sample_ret
# t-stat       12.099109       68.617233
# p-value       0.000000        0.000000
# skewness      1.790317        0.873542
# kurtosis     13.102461        5.712689
# Ann. Ret      0.132326        0.193268
# Ann. Vol      0.124143        0.491277
# Ann. IR       1.065916        0.393399
# occurance  1560.000000   368118.000000  , 'space':                 long_space  top_quantile_space  bottom_quantile_space  \
# Up_sp Mean        0.116282            0.116457               0.113992
# Up_sp Std         0.072931            0.125424               0.119630
# Up_sp IR          1.594411            0.928504               0.952872
# Up_sp Pct5        0.036434            0.001581               0.000000
# Up_sp Pct25       0.068107            0.033498               0.033120
# Up_sp Pct50       0.099740            0.082003               0.081839
# Up_sp Pct75       0.143856            0.156094               0.154428
# Up_sp Pct95       0.256807            0.349826               0.338823
# Up_sp Occur    1560.000000        72997.000000           74235.000000
# Down_sp Mean     -0.207010           -0.209735              -0.205689
# Down_sp Std       0.135748            0.324011               0.311555
# Down_sp IR       -1.524959           -0.647308              -0.660199
# Down_sp Pct5     -0.498857           -1.000800              -1.000800
# Down_sp Pct25    -0.283027           -0.160445              -0.167064
# Down_sp Pct50    -0.156684           -0.077292              -0.083317
# Down_sp Pct75    -0.113969           -0.032901              -0.036467
# Down_sp Pct95    -0.073311           -0.004706              -0.005828
# Down_sp Occur  1560.000000        72997.000000           74235.000000
#
#                  tmb_space  all_sample_space
# Up_sp Mean        0.329332          0.112937
# Up_sp Std         0.140819          0.120204
# Up_sp IR          2.338683          0.939546
# Up_sp Pct5        0.160825          0.000951
# Up_sp Pct25       0.229694          0.032774
# Up_sp Pct50       0.305066          0.080351
# Up_sp Pct75       0.396768          0.153046
# Up_sp Pct95       0.603003          0.336248
# Up_sp Occur    1560.000000     368118.000000
# Down_sp Mean     -0.329540         -0.201988
# Down_sp Std       0.148257          0.314436
# Down_sp IR       -2.222756         -0.642380
# Down_sp Pct5     -0.612011         -1.000800
# Down_sp Pct25    -0.404574         -0.157908
# Down_sp Pct50    -0.297909         -0.077409
# Down_sp Pct75    -0.228939         -0.033242
# Down_sp Pct95    -0.150217         -0.004891
# Down_sp Occur  1560.000000     368118.000000  }
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 15%
#
#
# Value of signals of Different Quantiles Statistics
#                min       max      mean       std  count    count %
# quantile
# 1         0.000000  0.483871  0.099535  0.059732  74405  20.172430
# 2         0.074004  0.535156  0.296728  0.063490  73769  20.000000
# 3         0.269450  0.908918  0.493160  0.064976  73763  19.998373
# 4         0.436433  0.865275  0.688813  0.065063  73769  20.000000
# 5         0.654649  1.000000  0.889803  0.062930  73139  19.829197
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_2\returns_report.pdf
# Information Analysis
#                  ic
# IC Mean       0.053
# IC Std.       0.120
# t-stat(IC)   17.142
# p-value(IC)   0.000
# IC Skew      -0.978
# IC Kurtosis   7.124
# Ann. IR       0.437
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_2\information_report.pdf
# {'ic':                 return_ic  upside_ret_ic  downside_ret_ic
# IC Mean      5.254652e-02  -5.133902e-02     1.189390e-01
# IC Std.      1.202902e-01   1.152994e-01     1.230834e-01
# t-stat(IC)   1.714250e+01  -1.747355e+01     3.792145e+01
# p-value(IC)  2.020501e-60   1.642917e-62    9.314020e-223
# IC Skew     -9.776699e-01  -6.995589e-01    -2.600347e-01
# IC Kurtosis  7.124153e+00   5.208000e+00     6.013619e+00
# Ann. IR      4.368313e-01  -4.452672e-01     9.663281e-01, 'ret':               long_ret  long_short_ret  top_quantile_ret  bottom_quantile_ret  \
# t-stat        7.305246        7.284149         38.044933            18.228929
# p-value       0.000000        0.000000          0.000000             0.000000
# skewness     -0.501081       -3.501169          0.835905             0.723278
# kurtosis      3.614943       49.018370          6.233161             3.316340
# Ann. Ret      0.217373        0.035432          0.234848             0.119713
# Ann. Vol      0.337754        0.055213          0.479919             0.514974
# Ann. IR       0.643583        0.641724          0.489348             0.232464
# occurance  1560.000000     1560.000000      73139.000000         74405.000000
#
#                tmb_ret  all_sample_ret
# t-stat       10.536817       68.507135
# p-value       0.000000        0.000000
# skewness     -0.041733        0.880159
# kurtosis      1.065056        5.796245
# Ann. Ret      0.112604        0.192889
# Ann. Vol      0.121303        0.491587
# Ann. IR       0.928280        0.392380
# occurance  1560.000000   368845.000000  , 'space':                 long_space  top_quantile_space  bottom_quantile_space  \
# Up_sp Mean        0.112795            0.108726               0.120266
# Up_sp Std         0.071029            0.120096               0.123750
# Up_sp IR          1.588011            0.905328               0.971841
# Up_sp Pct5        0.035382            0.001209               0.000132
# Up_sp Pct25       0.065714            0.031368               0.034949
# Up_sp Pct50       0.096638            0.076453               0.087460
# Up_sp Pct75       0.141454            0.146751               0.164625
# Up_sp Pct95       0.251194            0.329614               0.354550
# Up_sp Occur    1560.000000        73139.000000           74405.000000
# Down_sp Mean     -0.201836           -0.200848              -0.217156
# Down_sp Std       0.133678            0.319736               0.315858
# Down_sp IR       -1.509864           -0.628168              -0.687510
# Down_sp Pct5     -0.480645           -1.000800              -1.000800
# Down_sp Pct25    -0.282655           -0.150308              -0.178761
# Down_sp Pct50    -0.151533           -0.071060              -0.093472
# Down_sp Pct75    -0.107747           -0.029955              -0.042078
# Down_sp Pct95    -0.069684           -0.004517              -0.006450
# Down_sp Occur  1560.000000        73139.000000           74405.000000
#
#                  tmb_space  all_sample_space
# Up_sp Mean        0.332522          0.112855
# Down_sp IR       -1.566478           -0.618873              -0.699619
# Down_sp Pct5     -0.475413           -1.000800              -1.000800
# Down_sp Pct25    -0.277916           -0.146598              -0.188438
# Down_sp Pct50    -0.159043           -0.069675              -0.095047
# Down_sp Pct75    -0.112098           -0.028648              -0.042440
# Down_sp Pct95    -0.074810           -0.004092              -0.006303
# Down_sp Occur  1560.000000        85800.000000           87038.000000
#
#                  tmb_space  all_sample_space
# Up_sp Mean        0.351087          0.115375
# Up_sp Std         0.153746          0.160188
# Up_sp IR          2.283547          0.720243
# Up_sp Pct5        0.174287          0.000687
# Up_sp Pct25       0.242873          0.033323
# Up_sp Pct50       0.319274          0.081907
# Up_sp Pct75       0.441646          0.156063
# Up_sp Pct95       0.676214          0.340774
# Up_sp Occur    1560.000000     432200.000000
# Down_sp Mean     -0.324928         -0.204181
# Down_sp Std       0.135132          0.316809
# Down_sp IR       -2.404520         -0.644493
# Down_sp Pct5     -0.558564         -1.000800
# Down_sp Pct25    -0.405435         -0.159679
# Down_sp Pct50    -0.300981         -0.077284
# Down_sp Pct75    -0.229654         -0.032943
# Down_sp Pct95    -0.160218         -0.004737
# Down_sp Occur  1560.000000     432200.000000  }
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 16%
#
#
# Value of signals of Different Quantiles Statistics
#                min       max      mean       std  count    count %
# quantile
# 1         0.000000  0.682482  0.104164  0.062259  75785  20.162610
# 2         0.141199  0.959502  0.309326  0.063608  75178  20.001117
# 3         0.328155  0.975078  0.511407  0.063713  75192  20.004842
# 4         0.547664  0.996885  0.711716  0.061288  75178  20.001117
# 5         0.743068  1.000000  0.906399  0.057139  74536  19.830313
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_4\returns_report.pdf
# Information Analysis
#                  ic
# IC Mean       0.084
# IC Std.       0.119
# t-stat(IC)   27.704
# p-value(IC)   0.000
# IC Skew      -0.367
# IC Kurtosis   1.036
# Ann. IR       0.706
# Figure saved: C:\Users\Administrator\Desktop\样本外2010-2017\factor_4\information_report.pdf
# {'ic':                  return_ic  upside_ret_ic  downside_ret_ic
# IC Mean       8.426934e-02      -0.010266     1.321753e-01
# IC Std.       1.193679e-01       0.109969     1.108357e-01
# t-stat(IC)    2.770399e+01      -3.663340     4.679840e+01
# p-value(IC)  2.149904e-137       0.000257    4.521940e-298
# IC Skew      -3.669025e-01      -0.223724    -4.096260e-01
# IC Kurtosis   1.035909e+00       2.171200     9.020791e-01
# Ann. IR       7.059631e-01      -0.093351     1.192534e+00, 'ret':               long_ret  long_short_ret  top_quantile_ret  bottom_quantile_ret  \
# t-stat        8.507032       17.476480         53.454603            19.000518
# p-value       0.000000        0.000000          0.000000             0.000000
# skewness     -0.567324       -0.022692          0.735941             0.982793
# kurtosis      3.775449        1.131622          6.039415             5.432746
# Ann. Ret      0.251433        0.074224          0.321091             0.128695
# Ann. Vol      0.335487        0.048208          0.471444             0.536035
# Ann. IR       0.749459        1.539656          0.681079             0.240087
# occurance  1560.000000     1560.000000      74536.000000         75785.000000
#
#                tmb_ret  all_sample_ret
# t-stat       16.945017       83.376033
# p-value       0.000000        0.000000
# skewness     -0.033958        0.846310
# kurtosis      1.178261        6.032499
# Ann. Ret      0.185108        0.234191
# Ann. Vol      0.123998        0.495055
# Ann. IR       1.492834        0.473060
# occurance  1560.000000   375869.000000  , 'space':                 long_space  top_quantile_space  bottom_quantile_space  \
# Up_sp Mean        0.115014            0.114279               0.120713
# Up_sp Std         0.070316            0.117332               0.130401
# Up_sp IR          1.635660            0.973976               0.925707
# Up_sp Pct5        0.035293            0.001810               0.000000
# Up_sp Pct25       0.068713            0.036001               0.033522
# Up_sp Pct50       0.099318            0.084640               0.085266
# Up_sp Pct75       0.140976            0.154772               0.163936
# Up_sp Pct95       0.252523            0.328425               0.365179
# Up_sp Occur    1560.000000        74536.000000           75785.000000
# Down_sp Mean     -0.209265           -0.191796              -0.213412
# Down_sp Std       0.143712            0.313726               0.312787
# Down_sp IR       -1.456143           -0.611349              -0.682292
# Down_sp Pct5     -0.526561           -1.000800              -1.000800
# Down_sp Pct25    -0.279202           -0.142267              -0.177271
# Down_sp Pct50    -0.157579           -0.066448              -0.091709
# Down_sp Pct75    -0.111147           -0.027116              -0.041745
# Down_sp Pct95    -0.073357           -0.003499              -0.006483
# Down_sp Occur  1560.000000        74536.000000           75785.000000
#
#                  tmb_space  all_sample_space
# Up_sp Mean        0.348698          0.115052
# Up_sp Std         0.157578          0.121639
# Up_sp IR          2.212865          0.945850
# Up_sp Pct5        0.165152          0.000808
# Up_sp Pct25       0.240121          0.033939
# Up_sp Pct50       0.317509          0.082482
# Up_sp Pct75       0.423318          0.156101
# Up_sp Pct95       0.692921          0.339737
# Up_sp Occur    1560.000000     375869.000000
# Down_sp Mean     -0.334103         -0.194605
# Down_sp Std       0.157236          0.309143
# Down_sp IR       -2.124844         -0.629497
# Down_sp Pct5     -0.663210         -1.000800
# Down_sp Pct25    -0.412417         -0.151683
# Down_sp Pct50    -0.291817         -0.073527
# Down_sp Pct75    -0.225320         -0.031200
# Down_sp Pct95    -0.157553         -0.004315
# Down_sp Occur  1560.000000     375869.000000  }

# %%
import matplotlib.pyplot as plt
from jaqs_fxdayu.research.signaldigger.analysis import analysis
from jaqs_fxdayu.research import SignalDigger
def result_without_benchmark(comb_factors,name,method):
    obj = SignalDigger(output_folder="绝对收益样本内2010-2017/%s" % name,
                       output_format='pdf')
    obj.process_signal_before_analysis(signal=comb_factors[method].loc[:20170101],
                                   price=dv.get_ts("close_adj").loc[:20170101],
                                   high=dv.get_ts("high_adj").loc[:20170101], # 可为空
                                   low=dv.get_ts("low_adj").loc[:20170101],# 可为空
                                   n_quantiles=5,# quantile分类数
                                   mask=mask.loc[:20170101],# 过滤条件
                                   can_enter=can_enter.loc[:20170101],# 是否能进场
                                   can_exit=can_exit.loc[:20170101],# 是否能出场
                                   period=20,# 持有期
                                   #benchmark_price=zz800_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                   commission = 0.0008,
                                   )
    obj.create_full_report()
    plt.show()
    print(analysis(obj.signal_data,is_event=False,period=20))

# %%
result_without_benchmark(comb_factor_1,'factor_1_outbenchmark',"ic_weight")
result_without_benchmark(comb_factor_2,'factor_2_outbenchmark',"ic_weight")
result_without_benchmark(comb_factor_3,'factor_3_outbenchmark',"ic_weight")
result_without_benchmark(comb_factor_4,'factor_4_outbenchmark',"ic_weight")

# %%
#print(analysis(obj.signal_data,is_event=False,period=20))
